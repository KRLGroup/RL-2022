# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
class Unicycle:
    def __init__(self, x=None,max_linear_velocity=2, max_angular_velocity=np.pi/3):
        if x is None:
            x = np.zeros(3)
        self.x = x
        self.max_linear_velocity = max_linear_velocity
        self.max_angular_velocity = max_angular_velocity 
    
    def f(self, u, x=None, dt=0.1, save_x=True):
        if x is None:
            x = self.x
            
        # clip controls
        u[0] = np.clip(u[0],-self.max_linear_velocity,self.max_linear_velocity)
        u[1] = np.clip(u[1],-self.max_angular_velocity,self.max_angular_velocity)
        
        
        x_prime = x.copy()
        x_prime[0] = x[0] + u[0]*np.cos(x[2])*dt
        x_prime[1] = x[1] + u[0]*np.sin(x[2])*dt
        x_prime[2] = x[2] + u[1]*dt
        
        if save_x:
            self.x = x_prime
        return x_prime
    
    def getA(self, u, x=None, dt=0.1):
        if x is None:
            x = self.x
            
        A = np.eye(3) 
        A[:,2] += np.array([-u[0]*np.sin(x[2])*dt,
                            u[0]*np.cos(x[2])*dt,
                            0])
        return A
        
    def getB(self, x=None, dt=0.1):
        if x is None:
            x = self.x
            
        B = np.zeros((3,2))
        B[0,0] = np.cos(x[2])*dt
        B[1,0] = np.sin(x[2])*dt
        B[2,1] = dt
        return B
        
    def plot(self, x=None, ax=None):
        if x is None:
            x = self.x
            
        if ax is None:
            ax = plt
            
        get_T = lambda x, y, theta: np.array([[np.cos(theta),-np.sin(theta), x], [np.sin(theta),np.cos(theta), y], [0,0,0]])

        def get_point(T, x,y):
            x,y,_ = T@(np.array([[x,y,1]]).T).reshape(-1)
            return x,y

        x,y,theta = x
        T = get_T(x,y,theta)    
        points = [(0.1,0),(0,-0.05),(0,0.05),(0.1,0)]
        points = [get_point(T,*p) for p in points]
        ax.plot([p[0] for p in points], [p[1] for p in points], color='red')

# %% [markdown]
# ![](imgs/ilqr.png)

# %%
def lqr(F, C, T=100):
    V = np.zeros((3,3))
    Q = np.zeros((5,5))
    K = np.zeros((3,3))
    for t in range(T):
        
        # Q = ...
        
        Q_xx = Q[:3,:3]
        Q_uu = Q[3:,3:]
        Q_ux = Q[3:,:3]
        Q_xu = Q[:3,3:]
        
        # K = ...
        # V = ...
    return K

# %%
dt = 0.1
x = np.array([0.,0.,0.]) 
xf = np.array([2.000,2.000,np.pi/2])  
C = np.eye(5)
track = []
unicycle = Unicycle(x=x)
u = np.zeros(2)

for i in range(200):
    x = unicycle.x
    print(f'iteration = {i}')
    print(f'Current State = {x}')
    print(f'Desired State = {xf}')

    error = x - xf
    track.append(x)
    state_error_magnitude = np.linalg.norm(error)     
    print(f'State Error Magnitude = {state_error_magnitude}')

    B = unicycle.getB(x=x, dt=dt)
    A = unicycle.getA(np.zeros(2), x=x, dt=dt)
    
    # F = ...
    
    K = lqr(F, C) 
    
    # u = ...
    
    print(f'Control Input = {u}')

    x=unicycle.f(u, x=x, dt=dt)  
    
    if state_error_magnitude < 0.05:
        print(f"\nGoal Has Been Reached Successfully in {i} iterations!")
        break

    print()
# Out:
# iteration = 0 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 1 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 2 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 3 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 4 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 5 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 6 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 7 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 8 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 9 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 10 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 11 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 12 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 13 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 14 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 15 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 16 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 17 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 18 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 19 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 20 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 21 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 22 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 23 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 24 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 25 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 26 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 27 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 28 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 29 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 30 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 31 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 32 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 33 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 34 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 35 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 36 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 37 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 38 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 39 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 40 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 41 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 42 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 43 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 44 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 45 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 46 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 47 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 48 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 49 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 50 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 51 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 52 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 53 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 54 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 55 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 56 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 57 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 58 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 59 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 60 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 61 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 62 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 63 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 64 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 65 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 66 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 67 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 68 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 69 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 70 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 71 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 72 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 73 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 74 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 75 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 76 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 77 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 78 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 79 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 80 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 81 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 82 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 83 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 84 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 85 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 86 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 87 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 88 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 89 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 90 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 91 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 92 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 93 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 94 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 95 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 96 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 97 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 98 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 99 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 100 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 101 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 102 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 103 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 104 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 105 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 106 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 107 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 108 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 109 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 110 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 111 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 112 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 113 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 114 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 115 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 116 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 117 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 118 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 119 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 120 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 121 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 122 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 123 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 124 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 125 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 126 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 127 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 128 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 129 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 130 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 131 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 132 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 133 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 134 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 135 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 136 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 137 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 138 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 139 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 140 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 141 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 142 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 143 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 144 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 145 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 146 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 147 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 148 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 149 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 150 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 151 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 152 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 153 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 154 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 155 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 156 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 157 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 158 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 159 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 160 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 161 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 162 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 163 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 164 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 165 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 166 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 167 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 168 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 169 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 170 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 171 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 172 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 173 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 174 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 175 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 176 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 177 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 178 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 179 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 180 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 181 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 182 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 183 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 184 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 185 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 186 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 187 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 188 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 189 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 190 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 191 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 192 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 193 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 194 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 195 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 196 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 197 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 198 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]
#
# iteration = 199 seconds
# Current State = [0. 0. 0.]
# Desired State = [2.         2.         1.57079633]
# State Error Magnitude = 3.2353363194994644
# Control Input = [0. 0.]

# %%
plt.subplots(figsize=(10,10))
plt.xlim(-3,5)
plt.ylim(-3,5)
for x in track:
    unicycle.plot(x)
plt.show()
